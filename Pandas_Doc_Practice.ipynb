# %% [markdown]
# # Pandas Documentation Practice

# %% [markdown]
# ### By Aditya Singh

# %%
import pandas as pd

# %%
tmp = pd.DataFrame(
    {
        "Name": ["Aditya","Justin"],
        "Surname": ["Singh","Bieber"],
        "Age": [22,31],
        "Sex": ["Male","Male"],
        "Phone Number":[919999999,111111111]
    }
)
tmp
# Out:
#      Name Surname  Age   Sex  Phone Number
# 0  Aditya   Singh   22  Male     919999999
# 1  Justin  Bieber   31  Male     111111111

# %%
ages = pd.Series([22,22,22], name="New Age")
print(ages)

print("="*20)

print(tmp[["Name","Age"]])

print("="*20)

print(tmp["Age"].max())
print(tmp["Age"].min())

print("="*20)

print(tmp)

print("="*20)

print(tmp.describe())
# Out:
# 0    22
# 1    22
# 2    22
# Name: New Age, dtype: int64
# ...
#      Name  Age
# 0  Aditya   22
# 1  Justin   31
# ...
# 31
# 22
# ...
#      Name Surname  Age   Sex  Phone Number
# 0  Aditya   Singh   22  Male     919999999
# 1  Justin  Bieber   31  Male     111111111
# ...
#              Age  Phone Number
# count   2.000000  2.000000e+00
# mean   26.500000  5.155556e+08
# std     6.363961  5.719708e+08
# min    22.000000  1.111111e+08
# 25%    24.250000  3.133333e+08
# 50%    26.500000  5.155556e+08
# 75%    28.750000  7.177778e+08
# max    31.000000  9.200000e+08

# %%
org_data = pd.read_csv("H:\AI\Documentation Practice\Titanic-Dataset.csv")

# %%
data = org_data
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(data.head(6))
print("="*100)
print(data.tail(6))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.to_excel("H:\AI\Documentation Practice\Titanic.xlsx", sheet_name="Passengers", index=False)

# %%
a = pd.read_excel("H:\AI\Documentation Practice\Titanic.xlsx")
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = a
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
age = data["Age"]
print(age.head())

print("="*30)

print(type(age))
print(age.shape)

print("="*30)

age_sex = data[["Age", "Sex"]]
print(age_sex.head(), "\n", age_sex.shape)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64
# ...
# <class 'pandas.core.series.Series'>
# (891,)
# ...
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male
#  (891, 2)

# %%
# child = data[data["Age"] <= 6]["Age"]
child = data.loc[data["Age"] <= 6, "Age"]
print(child.head())
print(data["Age"] < 29)
print(child.shape)
# Out:
# 7     2.0
# 10    4.0
# 16    2.0
# 43    3.0
# 58    5.0
# Name: Age, dtype: float64
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Age, Length: 891, dtype: bool
# (47,)

# %%
cabin23 = data[data["Pclass"].isin([2,3])]
print(cabin23.head())
print("="*100)

cabin23 = data[(data["Pclass"] == 2) | (data["Pclass"] == 3)]
print(cabin23.head())
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  35.0      0      0            373450   8.0500   NaN        S
# 5   NaN      0      0            330877   8.4583   NaN        Q
# 7   2.0      3      1            349909  21.0750   NaN        S
# ...
#    PassengerId  Survived  Pclass                            Name     Sex  \
# ...

# %%
null = data[data["Age"].isnull()]["PassengerId"]
nnull = data[data["Age"].notna()]
# len(null)

print(null.count())
print(nnull.count())
# Out:
# 177
# PassengerId    714
# Survived       714
# Pclass         714
# Name           714
# Sex            714
# Age            714
# SibSp          714
# Parch          714
# Ticket         714
# Fare           714
# Cabin          185
# Embarked       712
# dtype: int64

# %%
adults = data.loc[data["Age"] > 18, ["Fare", "Survived","Embarked"]]
print(adults.describe())

adults
# Out:
#              Fare    Survived
# count  575.000000  575.000000
# mean    35.224840    0.382609
# std     55.476982    0.486447
# min      0.000000    0.000000
# 25%      8.050000    0.000000
# 50%     14.400000    0.000000
# 75%     33.760400    1.000000
# max    512.329200    1.000000
#         Fare  Survived Embarked
# 0     7.2500         0        S
# 1    71.2833         1        C
# 2     7.9250         1        S
# 3    53.1000         1        S
# 4     8.0500         0        S
# ..       ...       ...      ...
# 885  29.1250         0        Q
# 886  13.0000         0        S
# 887  30.0000         1        S
# 889  30.0000         1        C
# 890   7.7500         0        Q
#
# [575 rows x 3 columns]

# %%
print(adults.iloc[:60, 0:4].head())

con_btw_18_60 = (data["Age"] > 18) & (data["Age"] < 60)

temp = adults
temp.iloc[0:3,0:2] = "Error"
print(temp.head(7))

btw_18_60 = data.loc[con_btw_18_60, ["Age", "Survived", "Fare"]]
btw_18_60
print()
print("Accessed 4th element of column {Survived} using loc:", adults.loc[3, "Survived"])
print("Accessed 5th element of column {Fare} using iloc:", adults.iloc[4, 0])
# Out:
#       Fare  Survived Embarked
# 0   7.2500         0        S
# 1  71.2833         1        C
# 2   7.9250         1        S
# 3  53.1000         1        S
# 4   8.0500         0        S
#       Fare Survived Embarked
# 0    Error    Error        S
# 1    Error    Error        C
# 2    Error    Error        S
# 3     53.1        1        S
# 4     8.05        0        S
# 6  51.8625        0        S
# 8  11.1333        1        S
#
# Accessed 4th element of column {Survived} using loc: 1
# Accessed 5th element of column {Fare} using iloc: 8.05
# C:\Users\Aditya King\AppData\Local\Temp\ipykernel_12616\1019427297.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Error' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   temp.iloc[0:3,0:2] = "Error"
# ...

# %%
adults.iloc[2:5,1:2]
# Out:
#   Survived
# 2    Error
# 3        1
# 4        0

# %%
import matplotlib.pyplot as plt

# %%
fare_survived = data[["Fare", "Survived"]]
fare_survived.plot(color='purple', figsize=(7,3))
plt.show()
y = 3
fare_survived.plot.line(x="Fare", y="Survived", color='r', figsize=(7,y), legend=0, alpha=0.3)

plt.xlabel("Fare",size=13)
plt.ylabel("Survived", size=13)
plt.title("Fare vs Survived",size=23)
# plt.show()
# Out:
# Text(0.5, 1.0, 'Fare vs Survived')

# %%
print(data.info())
data.head(50).plot.line(x="PassengerId", y="Pclass" ,figsize=(10,5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
# <Axes: xlabel='PassengerId'>

# %%
data["Fare"].plot(kind='kde', color='r')
# Out:
# <Axes: ylabel='Density'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data["Survived : Fare"] = (data["Survived"]) / (data["Fare"])
# data.drop(columns = ["Survived : Fare"], inplace = True)
data["Survived : Fare"].to_frame().head(10)
# Out:
#    Survived : Fare
# 0         0.000000
# 1         0.014029
# 2         0.126183
# 3         0.018832
# 4         0.000000
# 5         0.000000
# 6         0.000000
# 7         0.000000
# 8         0.089821
# 9         0.033255

# %%
data_renamed = data.rename(columns = {
    "Survived : Fare" : "Survived/Fare"
})
# data.pop("Survived : Fare")
data = data_renamed
print(data.head(3))
data.iloc[0:,5:12].head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Survived/Fare
# 0      0         A/5 21171   7.2500   NaN        S       0.000000
# 1      0          PC 17599  71.2833   C85        C       0.014029
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0.126183
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  38.0      1      0          PC 17599  71.2833   C85        C
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
print(data["Fare"].mean())
print()
print(data[["Age", "Fare"]].median())
print()
agg = data.agg(
    {
        "Age": ["min", "max", "median","skew","mean"],
        "Fare": ["skew","min", "max", "median"]
    }
)

agg
# Out:
# 32.204207968574636
#
# Age     28.0000
# Fare    14.4542
# dtype: float64
#               Age        Fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# median  28.000000   14.454200
# skew     0.389108    4.787317
# mean    29.699118         NaN

# %%
import numpy as np

# %%
print(data[["Sex", "Age"]].groupby("Sex").mean())
print("="*30)

print(data[["Fare", "Sex"]].groupby("Sex").median().mean())
print("="*30)

print(data.groupby("Sex")["Age"].mean())
print("="*30)

print(data.groupby(["Sex", "Pclass"])["Age"].mean())
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645
# ...
# Fare    16.75
# dtype: float64
# ...
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64
# ...
# Sex     Pclass
# female  1         34.611765
#         2         28.722973
#         3         21.750000
# male    1         41.281386
#         2         30.740707
#         3         26.507589
# Name: Age, dtype: float64

# %%
a = data.groupby("Sex").mean(numeric_only=True)
print(a.select_dtypes(include=np.number))
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare  Survived/Fare
# Sex
# female  44.479818       0.038189
# male    25.523893            inf

# %%
print(data["Sex"].value_counts())
print("="*30)

print(data["Pclass"].value_counts())
print("="*30)

# print(data.groupby("Pclass")["Pclass"].size()) 
print(data.groupby("Pclass").size()) # .size() or .count()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64
# ...
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
# ...
# Pclass
# 1    216
# 2    184
# 3    491
# dtype: int64

# %%
print(data.sort_values(by="Age", ascending= 0).head(3)["Age"].to_frame())
print("="*30)
print(data.sort_values(by=["Age", "Pclass"], ascending= [0,0]).head(3)[["Pclass","Age"]])
# Out:
#       Age
# 630  80.0
# 851  74.0
# 493  71.0
# ...
#      Pclass   Age
# 630       1  80.0
# 851       3  74.0
# 96        1  71.0

# %%
filtered = data[data["Age"] == 5]
print(filtered["Age"].to_frame())
print()
filtered
# Out:
#      Age
# 58   5.0
# 233  5.0
# 448  5.0
# 777  5.0
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 58            59         1       2    West, Miss. Constance Mirium  female
# 233          234         1       3  Asplund, Miss. Lillian Gertrud  female
# 448          449         1       3  Baclini, Miss. Marie Catherine  female
# 777          778         1       3   Emanuel, Miss. Virginia Ethel  female
#
#      Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Survived/Fare
# 58   5.0      1      2  C.A. 34651  27.7500   NaN        S       0.036036
# 233  5.0      4      2      347077  31.3875   NaN        S       0.031860
# 448  5.0      2      1        2666  19.2583   NaN        C       0.051926
# 777  5.0      0      0      364516  12.4750   NaN        S       0.080160

# %%
filtered.sort_index(ascending=0).groupby("Sex").head()
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 777          778         1       3   Emanuel, Miss. Virginia Ethel  female
# 448          449         1       3  Baclini, Miss. Marie Catherine  female
# 233          234         1       3  Asplund, Miss. Lillian Gertrud  female
# 58            59         1       2    West, Miss. Constance Mirium  female
#
#      Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Survived/Fare
# 777  5.0      0      0      364516  12.4750   NaN        S       0.080160
# 448  5.0      2      1        2666  19.2583   NaN        C       0.051926
# 233  5.0      4      2      347077  31.3875   NaN        S       0.031860
# 58   5.0      1      2  C.A. 34651  27.7500   NaN        S       0.036036

# %%
print(filtered.pivot(columns=["Embarked", "SibSp"] , values="Age"))
print("="*30)

filt = pd.pivot_table(filtered, 
                      values="Fare", 
                      index="PassengerId", 
                      columns="Pclass", 
                      aggfunc= ["mean", "sum"], 
                      margins=1)
print(filt)

print(filt.plot.bar(
    title= "Mean", 
    xlabel=("Passenger ID"), 
    ylabel="Fare Mean", 
    alpha = 0.7, 
    figsize=(10,5)
))
# Out:
# Embarked    S         C    S
# SibSp       1    4    2    0
# 58        5.0  NaN  NaN  NaN
# 233       NaN  5.0  NaN  NaN
# 448       NaN  NaN  5.0  NaN
# 777       NaN  NaN  NaN  5.0
# ...
#               mean                        sum
# Pclass           2          3      All      2        3      All
# PassengerId
# 59           27.75        NaN  27.7500  27.75      NaN  27.7500
# 234            NaN  31.387500  31.3875    NaN  31.3875  31.3875
# 449            NaN  19.258300  19.2583    NaN  19.2583  19.2583
# 778            NaN  12.475000  12.4750    NaN  12.4750  12.4750
# All          27.75  21.040267  22.7177  27.75  63.1208  90.8708
# Axes(0.125,0.11;0.775x0.77)

# %%
print(filt)
# Out:
#               mean                        sum
# Pclass           2          3      All      2        3      All
# PassengerId
# 59           27.75        NaN  27.7500  27.75      NaN  27.7500
# 234            NaN  31.387500  31.3875    NaN  31.3875  31.3875
# 449            NaN  19.258300  19.2583    NaN  19.2583  19.2583
# 778            NaN  12.475000  12.4750    NaN  12.4750  12.4750
# All          27.75  21.040267  22.7177  27.75  63.1208  90.8708

# %%
# filt = filt.unstack(level=1).stack(level="Pclass")
filt
# Out:
#       PassengerId  Pclass
# mean  59           2         27.750000
#                    All       27.750000
#       234          3         31.387500
#                    All       31.387500
#       449          3         19.258300
#                    All       19.258300
#       778          3         12.475000
#                    All       12.475000
#       All          2         27.750000
#                    3         21.040267
#                    All       22.717700
# sum   59           2         27.750000
#                    All       27.750000
#       234          3         31.387500
#                    All       31.387500
#       449          3         19.258300
#                    All       19.258300
#       778          3         12.475000
#                    All       12.475000
#       All          2         27.750000
#                    3         63.120800
#                    All       90.870800
# dtype: float64

# %%
filt.reset_index()
# Out:
#    level_0 PassengerId Pclass          0
# 0     mean          59      2  27.750000
# 1     mean          59    All  27.750000
# 2     mean         234      3  31.387500
# 3     mean         234    All  31.387500
# 4     mean         449      3  19.258300
# 5     mean         449    All  19.258300
# 6     mean         778      3  12.475000
# 7     mean         778    All  12.475000
# 8     mean         All      2  27.750000
# 9     mean         All      3  21.040267
# 10    mean         All    All  22.717700
# 11     sum          59      2  27.750000
# 12     sum          59    All  27.750000
# 13     sum         234      3  31.387500
# 14     sum         234    All  31.387500
# 15     sum         449      3  19.258300
# 16     sum         449    All  19.258300
# 17     sum         778      3  12.475000
# 18     sum         778    All  12.475000
# 19     sum         All      2  27.750000
# 20     sum         All      3  63.120800
# 21     sum         All    All  90.870800

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived/Fare'],
#       dtype='object')

# %%
a = data.iloc[:5,:6]
b = data.iloc[:5,6:]

# %%
ab = pd.concat([a,b], axis = 0, ignore_index=1)
print(a.shape)
print(b.shape)
print(ab.shape)
ab
# Out:
# (5, 6)
# (5, 7)
# (10, 13)
#    PassengerId  Survived  Pclass  \
# 0          1.0       0.0     3.0
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
# 5          NaN       NaN     NaN
# 6          NaN       NaN     NaN
# 7          NaN       NaN     NaN
# 8          NaN       NaN     NaN
# 9          NaN       NaN     NaN
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    NaN
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    NaN
# 2                             Heikkinen, Miss. Laina  female  26.0    NaN
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    NaN
# 4                           Allen, Mr. William Henry    male  35.0    NaN
# 5                                                NaN     NaN   NaN    1.0
# ...

# %%
ab.drop(ab.index[5:])
# Out:
#    PassengerId  Survived  Pclass  \
# 0          1.0       0.0     3.0
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    NaN
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    NaN
# 2                             Heikkinen, Miss. Laina  female  26.0    NaN
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    NaN
# 4                           Allen, Mr. William Henry    male  35.0    NaN
#
#    Parch Ticket  Fare Cabin Embarked  Survived/Fare
# 0    NaN    NaN   NaN   NaN      NaN            NaN
# 1    NaN    NaN   NaN   NaN      NaN            NaN
# 2    NaN    NaN   NaN   NaN      NaN            NaN
# 3    NaN    NaN   NaN   NaN      NaN            NaN
# 4    NaN    NaN   NaN   NaN      NaN            NaN

# %%
merged = pd.merge(a, b, left_index=True, right_index=True)
merged
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Survived/Fare
# 0      0         A/5 21171   7.2500   NaN        S       0.000000
# 1      0          PC 17599  71.2833   C85        C       0.014029
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0.126183
# ...

# %%
merged.Embarked.unique()
# Out:
# array(['S', 'C'], dtype=object)

# %%
date = pd.to_datetime(merged["PassengerId"])
date
# Out:
# 0   1970-01-01 00:00:00.000000001
# 1   1970-01-01 00:00:00.000000002
# 2   1970-01-01 00:00:00.000000003
# 3   1970-01-01 00:00:00.000000004
# 4   1970-01-01 00:00:00.000000005
# Name: PassengerId, dtype: datetime64[ns]

# %%
print(date.max())
print(date.min())
print(date.mean())

print()

merged["Ticket"].max(), merged["Ticket"].min()
# Out:
# 1970-01-01 00:00:00.000000005
# 1970-01-01 00:00:00.000000001
# 1970-01-01 00:00:00.000000003
# ('STON/O2. 3101282', '113803')

# %%
print(date.index)

print("|\|/|"*20)

date.dt.year, date.dt.month, date.dt.weekday, date.dt.day
# Out:
# RangeIndex(start=0, stop=5, step=1)
# |\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/|
# (0    1970
#  1    1970
#  2    1970
#  3    1970
#  4    1970
#  Name: PassengerId, dtype: int32,
#  0    1
#  1    1
#  2    1
#  3    1
#  4    1
#  Name: PassengerId, dtype: int32,
#  0    3
#  1    3
#  2    3
#  3    3
#  4    3
#  Name: PassengerId, dtype: int32,
#  0    1
#  1    1
#  2    1
#  3    1
#  4    1
#  Name: PassengerId, dtype: int32)

# %%
print(data.loc[0:-1])

print()

print(data.iloc[-1:0])

print()

print(data.columns[0:2])

print()

print(data.iloc[:2,0:2])
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Survived/Fare]
# Index: []
#
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Survived/Fare]
# Index: []
#
# Index(['PassengerId', 'Survived'], dtype='object')
#
#    PassengerId  Survived
# 0            1         0
# 1            2         1

# %%
print(data["Name"].str.lower())
print("|\|/|"*20)

print(data["Name"].str.upper())
print("|\|/|"*20)

print(data["Name"].str.isalnum().head(3))
print("|\|/|"*20)

print(data["Name"].str.split(",").head(5))
print("|\|/|"*20)

data["Surname"] = data["Name"].str.split(",").str.get(0)
print(data["Surname"].head(5))

print("|\|/|"*20)
print(data["Name"].str.contains("Countess").head(5))

print("|\|/|"*20)
print(data[data["Name"].str.contains("Countess")])

print("|\|/|"*20)
print(data["Name"].str.len().head())
print(data["Name"].str.len().idxmax())
print(data.loc[data["Name"].str.len().idxmax(), "Name"])

print("|\|/|"*20)
print(data["Sex"].replace({"male":"M", "female":"F"}).head())


data.head()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object
# |\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/||\|/|
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# ...

# %%
last = data.pop(data.columns[-1])
# data.insert(4, last)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[417], line 2
#       1 last = data.pop(data.columns[-1])
# ----> 2 data.insert(4, last)
#
# TypeError: DataFrame.insert() missing 1 required positional argument: 'value'
