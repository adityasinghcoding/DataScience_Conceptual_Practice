# %% [markdown]
# # Seaborn Documentation Practice
# ## By Aditya Singh
# ### GitHub: adityasinghcoding

# %%
import seaborn as sns

# %%
sns.set_theme(style='darkgrid')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip_plot = sns.relplot(data=tips, x = 'total_bill', y = 'tip', col='time', hue='smoker', style='smoker', size='size')
tip_plot

# %%
bullet_analysis = sns.load_dataset('dots')

# %%
bullet_analysis.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(
    data=bullet_analysis, x='time', y='firing_rate', col='align', 
    hue='choice', size='coherence', style='choice', facet_kws=dict(sharex=False), kind='line', legend=False)

# %%
sns.relplot(data=bullet_analysis, x = 'time', y='firing_rate', col='align',
            hue='choice', style='choice', facet_kws =dict(sharex=False), kind='line')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(data=tips, x='total_bill', y='tip', col='time', hue='smoker')

# %%
sns.displot(data=tips, x='total_bill', col='time', kde=True, hue='time')

# %%
sns.displot(data=tips, x='total_bill', y='tip', col='time', hue='time')

# %%
sns.displot(data=tips, kind='ecdf', x='total_bill', col='time', hue='smoker', rug=True)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(data=tips, kind='swarm', x='sex', y='total_bill', hue='tip')

# %%
sns.catplot(data=tips, kind='swarm', x='sex', y='total_bill', hue='tip', col='sex')

# %%
import matplotlib.pyplot as plt

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(10,5))

sns.swarmplot(data=tips, x='sex', y='total_bill', hue='tip', ax=ax1)
ax1.set_title('Gender vs Total Bill with TIP comparison', weight='heavy')

sns.swarmplot(data=tips, x='sex', y='total_bill', hue='total_bill', ax=ax2)
ax2.set_title('Gender vs Total Bill with Total Bill intensity', weight='heavy')

plt.tight_layout()
plt.show()

# %%
sns.catplot(data=tips, kind='violin', x='day', y='total_bill', hue='sex', split=True)

# %%
sns.catplot(data=tips, kind='bar', x='day', y='total_bill', hue='day', col='smoker')

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.jointplot(data=penguins, x='flipper_length_mm', y='bill_length_mm', hue='species')

# %%
sns.pairplot(data=penguins, hue='species')

# %%
g = sns.PairGrid(penguins, hue='species', corner=False)

# %%
g = sns.PairGrid(penguins, hue='species', corner=False)
g.map_lower(sns.kdeplot, hue=None, levels=5, color='.3')

# %%
g = sns.PairGrid(penguins, hue='species', corner=False)
g.map_lower(sns.kdeplot, hue=None, levels=5, color='.1')
g.map_lower(sns.scatterplot, marker='*')

# %%
g = sns.PairGrid(penguins, hue='species', corner=False)
g.map_lower(sns.kdeplot, hue=None, levels=5, color='.1')
g.map_lower(sns.scatterplot, marker='*')
g.map_diag(sns.histplot, element='step', linewidth=2, kde=True)

# %%
g = sns.PairGrid(penguins, hue='species', corner=True)
g.map_lower(sns.kdeplot, hue=None, levels=5, color='.1')
g.map_lower(sns.scatterplot, marker='*')
g.map_diag(sns.histplot, element='step', linewidth=2, kde=True)
g.add_legend(frameon=True)
g.legend.set_bbox_to_anchor((.61, .6))

# %%
sns.set_theme(style='ticks', font_scale=1.5)
g = sns.relplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', 
                hue='body_mass_g', palette='crest', marker='x', s=100)

g.set_axis_labels('Bill length(mm)', 'Bill depth(mm)', labelpad=6)
g.legend.set_title('Body mass(g)')
g.figure.set_size_inches(10,5)
g.ax.margins(.16)
g.despine(trim=True)
